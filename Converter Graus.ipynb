# %%
#graus em fahrenheit

g = float(input('digite o valor em C°: '))

f = (g*1.8) + 32

print('a temperatura de C°{} corresponde á {}F'.format(g,f))
# Out:
# a temperatura de C°32.0 corresponde á 89.6F

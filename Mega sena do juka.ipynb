# %%
#mega sena do juka


print('bem vindo a mega sena do juka!')
print('digite os 6 numeros desejados: ')

n1 = int(input('digite o primeiro numero '))

if n1 % 2 == 0:
    

    n2 = int(input('digite o segundo numero: '))

    n3 = int(input('digite o terceiro numero: '))

    while n3 % 2 != 0:

        print('numero digitador impar, digite um numero par')

        n3 = int(input('Digite o terceiro número novamente: '))

    n4 = int(input('Digite o quarto numero: '))

    while n4 % 2 == 0:

        print('o Quarto numero deve ser impar, digite novamente: ')

        n4 = int(input('Digite o quarto numero: '))

    n5 = int(input('digite o quinto numero: '))

    n6 = int(input('digite o sexto numero: '))

    while n6 % 2 == 0:
         
        print('o sexto numero deve ser impar, digite novamente: ')

        n6 = int(input('digite o sexto numero: '))


if n1 % 2!= 0:

    n2 = int(input('digite o segundo numero: '))

    n3 = int(input('digite o terceiro numero: '))

    while n3 % 2 == 0:

        print('numero digitador Par, digite um numero Impar')

        n3 = int(input('Digite o terceiro número novamente: '))

    n4 = int(input('Digite o quarto numero: '))

    while n4 % 2 != 0:

        print('o Quarto numero deve ser Par, digite novamente: ')

        n4 = int(input('Digite o quarto numero: '))

    n5 = int(input('digite o quinto numero: '))

    n6 = int(input('digite o sexto numero: '))

    while n6 % 2 != 0:
         
        print('o sexto numero deve ser par, digite novamente: ')

        n6 = int(input('digite o sexto numero: '))

    
soma_total = sum(n1,n2,n3,n4,n5,n6)
# Out:
# bem vindo a mega sena do juka!
# digite os 6 numeros desejados:
# numero digitador Par, digite um numero Impar
# o Quarto numero deve ser Par, digite novamente:
# o sexto numero deve ser par, digite novamente:

# %%
#desconto de 5%

preco = float(input('digite o valor do produto: R$'))

desconto = 0.05

valor_final = preco - (preco * desconto)

print('o valor do produto com o desconto de 5% é: R$ ',valor_final)
# Out:
# o valor do produto com o desconto de 5% é: R$  9.5

# %%
numero = int(input('me diga um numero: '))

if numero % 2 == 0:
    print( '{} é um numero par'.format(numero))

else:
    print('{} é um numero impar'.format(numero))
# Out:
# 13 é um numero impar

# %%
print('\033/7;45molá mundo')
# Out:
# olá mundo

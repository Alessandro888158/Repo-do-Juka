# %%
#dolar

dolar_preco = 5.25

real = float(input('digite o saldo de sua conta : '))

dolar = real / dolar_preco

print('com R${} voce pode comprar $ {:.2f} dolares'.format(real, dolar))
# Out:
# com R$5.5 voce pode comprar $ 1.05 dolares
